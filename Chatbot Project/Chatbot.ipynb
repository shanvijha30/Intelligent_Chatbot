# %%
import keras
import nltk
import pickle
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
from tensorflow.keras.optimizers import SGD
import random

# %%
# import datetime
# from googlesearch import *
# import webbrowser
# import requests
# from pycricbuzz import Cricbuzz
# import billboard
# import time
# from pygame import mixer
# import COVID19Py

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
words=[]
classes=[]
documents=[]
ignore=['?','!',',',"'s"]

data_file=open('intents.json').read()
intents=json.loads(data_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        w=nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
           
words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore]
words=sorted(list(set(words)))
classes=sorted(list(set(classes)))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
#training data
training=[]
output_empty=[0]*len(classes)

for doc in documents:
    bag=[]
    pattern=doc[0]
    pattern=[ lemmatizer.lemmatize(word.lower()) for word in pattern ]
    
    for word in words:
        if word in pattern:
            bag.append(1)
        else:
            bag.append(0)
    output_row=list(output_empty)
    output_row[classes.index(doc[1])]=1
    
    training.append([bag,output_row])

# %%
random.shuffle(training) 


train_x = np.array([pair[0] for pair in training])
train_y = np.array([pair[1] for pair in training])


max_len = len(train_x[0])
train_x = np.array([np.pad(vec, (0, max_len - len(vec)), 'constant') for vec in train_x])


train_x = np.array(train_x)
train_y = np.array(train_y)

# %%
#Model
model=Sequential()
model.add(Dense(128,activation='relu',input_shape=(len(train_x[0]),)))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))

# %%
sgd=SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.fit(np.array(train_x),np.array(train_y),epochs=200, batch_size=10,verbose=1)    
model.save('chatbotmodel.model')
# Out:
# Epoch 1/200
# 14/14 [==============================] - 1s 4ms/step - loss: 3.6921 - accuracy: 0.0216
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 3.6906 - accuracy: 0.0216
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 3.6785 - accuracy: 0.0719
# Epoch 4/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.6457 - accuracy: 0.0863
# Epoch 5/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.5913 - accuracy: 0.0504
# Epoch 6/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.5891 - accuracy: 0.0935
# Epoch 7/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.5666 - accuracy: 0.0576
# Epoch 8/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.5390 - accuracy: 0.0863
# Epoch 9/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.5239 - accuracy: 0.0863
# Epoch 10/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.4690 - accuracy: 0.0935
# Epoch 11/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.4341 - accuracy: 0.0935
# Epoch 12/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.3761 - accuracy: 0.1439
# Epoch 13/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.3001 - accuracy: 0.1511
# Epoch 14/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.2410 - accuracy: 0.1655
# Epoch 15/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.1522 - accuracy: 0.1799
# Epoch 16/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.1057 - accuracy: 0.1799
# Epoch 17/200
# 14/14 [==============================] - 0s 3ms/step - loss: 3.0331 - accuracy: 0.1799
# Epoch 18/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.9090 - accuracy: 0.2302
# Epoch 19/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9445 - accuracy: 0.1942
# Epoch 20/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7591 - accuracy: 0.2878
# Epoch 21/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.7818 - accuracy: 0.2518
# Epoch 22/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.7515 - accuracy: 0.2158
# Epoch 23/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.5692 - accuracy: 0.3094
# Epoch 24/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.4948 - accuracy: 0.2806
# Epoch 25/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.4194 - accuracy: 0.3165
# Epoch 26/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.3961 - accuracy: 0.3237
# Epoch 27/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.3871 - accuracy: 0.3453
# Epoch 28/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.2409 - accuracy: 0.3669
# Epoch 29/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.2318 - accuracy: 0.3669
# Epoch 30/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.0998 - accuracy: 0.3813
# Epoch 31/200
# 14/14 [==============================] - 0s 3ms/step - loss: 2.0552 - accuracy: 0.4029
# Epoch 32/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.8607 - accuracy: 0.4460
# Epoch 33/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.8132 - accuracy: 0.4964
# Epoch 34/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.7895 - accuracy: 0.4892
# Epoch 35/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.8329 - accuracy: 0.4604
# Epoch 36/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.6548 - accuracy: 0.5540
# Epoch 37/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.4764 - accuracy: 0.5827
# Epoch 38/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.4349 - accuracy: 0.5899
# Epoch 39/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3045 - accuracy: 0.5899
# Epoch 40/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2384 - accuracy: 0.6906
# Epoch 41/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2495 - accuracy: 0.6259
# Epoch 42/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3833 - accuracy: 0.5827
# Epoch 43/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2298 - accuracy: 0.6403
# Epoch 44/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1114 - accuracy: 0.7050
# Epoch 45/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9161 - accuracy: 0.7770
# Epoch 46/200
# 14/14 [==============================] - 0s 4ms/step - loss: 1.2131 - accuracy: 0.6259
# Epoch 47/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9620 - accuracy: 0.7626
# Epoch 48/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9434 - accuracy: 0.7338
# Epoch 49/200
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0845 - accuracy: 0.6906
# Epoch 50/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8798 - accuracy: 0.7770
# Epoch 51/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.8411 - accuracy: 0.7338
# Epoch 52/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9357 - accuracy: 0.7122
# Epoch 53/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.7160 - accuracy: 0.8129
# Epoch 54/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.7486 - accuracy: 0.7554
# Epoch 55/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.7575 - accuracy: 0.7986
# Epoch 56/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7182 - accuracy: 0.7770
# Epoch 57/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7954 - accuracy: 0.7986
# Epoch 58/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6452 - accuracy: 0.8058
# Epoch 59/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5203 - accuracy: 0.8633
# Epoch 60/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6770 - accuracy: 0.7986
# Epoch 61/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6408 - accuracy: 0.7986
# Epoch 62/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4716 - accuracy: 0.8777
# Epoch 63/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5815 - accuracy: 0.8129
# Epoch 64/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5579 - accuracy: 0.8201
# Epoch 65/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5563 - accuracy: 0.8489
# Epoch 66/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5438 - accuracy: 0.8705
# Epoch 67/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5289 - accuracy: 0.7986
# Epoch 68/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5931 - accuracy: 0.7698
# Epoch 69/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4570 - accuracy: 0.8417
# Epoch 70/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5241 - accuracy: 0.8489
# Epoch 71/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4150 - accuracy: 0.8417
# Epoch 72/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4279 - accuracy: 0.8921
# Epoch 73/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.7914
# Epoch 74/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.9065
# Epoch 75/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4786 - accuracy: 0.8201
# Epoch 76/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3644 - accuracy: 0.9137
# Epoch 77/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4568 - accuracy: 0.8705
# Epoch 78/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8273
# Epoch 79/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8993
# Epoch 80/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8993
# Epoch 81/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4467 - accuracy: 0.8561
# Epoch 82/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4112 - accuracy: 0.8777
# Epoch 83/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8849
# Epoch 84/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4316 - accuracy: 0.8921
# Epoch 85/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4185 - accuracy: 0.8777
# Epoch 86/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5002 - accuracy: 0.8273
# Epoch 87/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.8561
# Epoch 88/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2941 - accuracy: 0.9137
# Epoch 89/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3836 - accuracy: 0.8849
# Epoch 90/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3102 - accuracy: 0.9281
# Epoch 91/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8849
# Epoch 92/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4134 - accuracy: 0.8777
# Epoch 93/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9496
# Epoch 94/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3405 - accuracy: 0.9137
# Epoch 95/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3466 - accuracy: 0.9137
# Epoch 96/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2485 - accuracy: 0.9353
# Epoch 97/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3210 - accuracy: 0.8993
# Epoch 98/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3089 - accuracy: 0.8993
# Epoch 99/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.9353
# Epoch 100/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2615 - accuracy: 0.9281
# Epoch 101/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3292 - accuracy: 0.8777
# Epoch 102/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2729 - accuracy: 0.9065
# Epoch 103/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2922 - accuracy: 0.8993
# Epoch 104/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8849
# Epoch 105/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2796 - accuracy: 0.9065
# Epoch 106/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2825 - accuracy: 0.9137
# Epoch 107/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2789 - accuracy: 0.9065
# Epoch 108/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2759 - accuracy: 0.8993
# Epoch 109/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2680 - accuracy: 0.9209
# Epoch 110/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2258 - accuracy: 0.9281
# Epoch 111/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3533 - accuracy: 0.8849
# Epoch 112/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3007 - accuracy: 0.8777
# Epoch 113/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3403 - accuracy: 0.8993
# Epoch 114/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3875 - accuracy: 0.8921
# Epoch 115/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2281 - accuracy: 0.9209
# Epoch 116/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2100 - accuracy: 0.9496
# Epoch 117/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2731 - accuracy: 0.9065
# Epoch 118/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2965 - accuracy: 0.9065
# Epoch 119/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4277 - accuracy: 0.8705
# Epoch 120/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3288 - accuracy: 0.9137
# Epoch 121/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1985 - accuracy: 0.9496
# Epoch 122/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9281
# Epoch 123/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2831 - accuracy: 0.9281
# Epoch 124/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2665 - accuracy: 0.9281
# Epoch 125/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2143 - accuracy: 0.9496
# Epoch 126/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9712
# Epoch 127/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1526 - accuracy: 0.9568
# Epoch 128/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2140 - accuracy: 0.9281
# Epoch 129/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.9640
# Epoch 130/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2963 - accuracy: 0.8993
# Epoch 131/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1756 - accuracy: 0.9281
# Epoch 132/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2207 - accuracy: 0.9281
# Epoch 133/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.9209
# Epoch 134/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1885 - accuracy: 0.9424
# Epoch 135/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1518 - accuracy: 0.9640
# Epoch 136/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1797 - accuracy: 0.9424
# Epoch 137/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1728 - accuracy: 0.9424
# Epoch 138/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2259 - accuracy: 0.9281
# Epoch 139/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1933 - accuracy: 0.9281
# Epoch 140/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.9065
# Epoch 141/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1978 - accuracy: 0.9353
# Epoch 142/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9712
# Epoch 143/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1167 - accuracy: 0.9640
# Epoch 144/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.9137
# Epoch 145/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1483 - accuracy: 0.9712
# Epoch 146/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1859 - accuracy: 0.9424
# Epoch 147/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1417 - accuracy: 0.9496
# Epoch 148/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9496
# Epoch 149/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1684 - accuracy: 0.9568
# Epoch 150/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1573 - accuracy: 0.9568
# Epoch 151/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1482 - accuracy: 0.9353
# Epoch 152/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2061 - accuracy: 0.9353
# Epoch 153/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1889 - accuracy: 0.9209
# Epoch 154/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9424
# Epoch 155/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2278 - accuracy: 0.9209
# Epoch 156/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1905 - accuracy: 0.9568
# Epoch 157/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2049 - accuracy: 0.9353
# Epoch 158/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9784
# Epoch 159/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1879 - accuracy: 0.9353
# Epoch 160/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9784
# Epoch 161/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1904 - accuracy: 0.9424
# Epoch 162/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2251 - accuracy: 0.9209
# Epoch 163/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1262 - accuracy: 0.9712
# Epoch 164/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1328 - accuracy: 0.9496
# Epoch 165/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1469 - accuracy: 0.9568
# Epoch 166/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1469 - accuracy: 0.9568
# Epoch 167/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9496
# Epoch 168/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9568
# Epoch 169/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1778 - accuracy: 0.9281
# Epoch 170/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1689 - accuracy: 0.9496
# Epoch 171/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1325 - accuracy: 0.9640
# Epoch 172/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1579 - accuracy: 0.9424
# Epoch 173/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2151 - accuracy: 0.9353
# Epoch 174/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1720 - accuracy: 0.9568
# Epoch 175/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1770 - accuracy: 0.9353
# Epoch 176/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9640
# Epoch 177/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2030 - accuracy: 0.8993
# Epoch 178/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1449 - accuracy: 0.9568
# Epoch 179/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1005 - accuracy: 0.9856
# Epoch 180/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1851 - accuracy: 0.9281
# Epoch 181/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1637 - accuracy: 0.9209
# Epoch 182/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1748 - accuracy: 0.9496
# Epoch 183/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2030 - accuracy: 0.9424
# Epoch 184/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2899 - accuracy: 0.9065
# Epoch 185/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2180 - accuracy: 0.9424
# Epoch 186/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1638 - accuracy: 0.9424
# Epoch 187/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1781 - accuracy: 0.9424
# Epoch 188/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.9496
# Epoch 189/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.8993
# Epoch 190/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1662 - accuracy: 0.9353
# Epoch 191/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1584 - accuracy: 0.9424
# Epoch 192/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1644 - accuracy: 0.9496
# Epoch 193/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1801 - accuracy: 0.9424
# Epoch 194/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2948 - accuracy: 0.9137
# Epoch 195/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1673 - accuracy: 0.9712
# Epoch 196/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1916 - accuracy: 0.9424
# Epoch 197/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9568
# Epoch 198/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1776 - accuracy: 0.9424
# Epoch 199/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1645 - accuracy: 0.9424
# Epoch 200/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9424
# INFO:tensorflow:Assets written to: chatbotmodel.model\assets

# %%
from keras.models import load_model
model = load_model('chatbotmodel.model')
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
#Predict
def clean_up(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=[ lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def create_bow(sentence,words):
    sentence_words=clean_up(sentence)
    bag=list(np.zeros(len(words)))
    
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence,model):
    p=create_bow(sentence,words)
    res=model.predict(np.array([p]))[0]
    threshold=0.8
    results=[[i,r] for i,r in enumerate(res) if r>threshold]
    results.sort(key=lambda x: x[1],reverse=True)
    return_list=[]
    
    for result in results:
        return_list.append({'intent':classes[result[0]],'prob':str(result[1])})
    return return_list

# %%
def get_response(return_list,intents_json):
    
    if len(return_list)==0:
        tag='noanswer'
    else:    
        tag=return_list[0]['intent']

    list_of_intents= intents_json['intents']    
    for i in list_of_intents:
        if tag==i['tag'] :
            result= random.choice(i['responses'])
    return result

# %%
def response(text):
    return_list=predict_class(text,model)
    response=get_response(return_list,intents)
    return response

# %%
# while(1):
#     x=input()
#     print(response(x))
# #Self learning
# print('Help me Learn?')
# tag=input('Please enter general category of your question  ')
# flag=-1
# for i in range(len(intents['intents'])):
#     if tag.lower() in intents['intents'][i]['tag']:
#         intents['intents'][i]['patterns'].append(input('Enter your message: '))
#         intents['intents'][i]['responses'].append(input('Enter expected reply: '))        
#         flag=1

# if flag==-1:
    
#     intents['intents'].append (
#         {'tag':tag,
#          'patterns': [input('Please enter your message')],
#          'responses': [input('Enter expected reply')]})
    
# with open('intents.json','w') as outfile:
#     outfile.write(json.dumps(intents,indent=4))

# %%
response("Hi")
# Out:
# 'Hey there, how can I help you today?'

# %% [raw]
# response("Goodbye")

# %%
response("Goodbye")
# Out:
# 'Goodbye! Have a great day.'
